# %% [markdown]
# ## 데이터 이해

# %% [markdown]
# ### 이 데이터는 무슨 데이터인가?
# 해당 데이터는 용접 공정 측정 데이터 입니다.
#
# ---
#
# - Training_Data.csv
#
#     => 훈련용 데이터
#
#     => 135,759개 레코드
#
# ---
#
# - WeldingTest_01_OK.csv
#
# - WeldingTest_02_OK.csv
#
#     => 정상(OK) 테스트 데이터
#
# ---
#
# - WeldingTest_03_NG.csv
#
# - WeldingTest_04_NG.csv
#
#     => 불량(NG) 테스트 데이터
# ---
#
# ### raw_data:
# * 모든 CSV는 동일한 9개의 컬럼을 가짐
# * PageNo,  Speed,  Length,  RealPower,  SetFrequency,  SetDuty,  SetPower,  GateOnTime,  WorkingTime
# ---
# * 누락값 없음.
# row 수
# * Training_Data.csv: 135,759행
# * WeldingTest_01_OK.csv: 1,950행
# * WeldingTest_02_OK.csv: 1,872행
# * WeldingTest_03_NG.csv: 1,053행
# * WeldingTest_04_NG.csv: 351행
#
# ---
# ### 라벨 파일
# * WeldingTest_03_NG_Label.csv: 1,053행
# * 라벨 분포: 0 = 1,034개, 1 = 19개
# * WeldingTest_04_NG_Label.csv: 351행
# * 라벨 분포: 0 = 78개, 1 = 273개
#
# => label 컬럼은 0/1 분류이며, 파일명 기반으로 1이 NG(불량) 신호일 가능성이 큼.
#
# ---
